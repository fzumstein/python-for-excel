# %% [markdown]
# # stocks.xlsx

# %%
import pandas as pd
import xlwings as xw
from functools import partial
import matplotlib.pyplot as plt

# %%
def xl_base(table_name, headers=True, wb_path=None):
    wb = xw.Book(wb_path)
    for sht in wb.sheets:
        for t in sht.tables:
                if t.name == table_name.split('[')[0]:
                    tbl = t
                break
    return tbl.range.options(pd.DataFrame, index=False).value

# %%
# Partial function for stocks.xlsx
xl = partial(xl_base, wb_path="/Users/felix/dev/python-for-excel-2e/src/xl/stocks.xlsx")

# %%
TableMSFT_df=xl("TableMSFT[[#Headers],[#Data]]", headers=True)

# %%
#Load TableAAPL, TableAMZN, and TableGOOGL data from Excel
# Attempt to load all four tables
TableAAPL_df = xl("TableAAPL[[#Headers],[#Data]]", headers=True)
TableAMZN_df = xl("TableAMZN[[#Headers],[#Data]]", headers=True)
TableGOOGL_df = xl("TableGOOGL[[#Headers],[#Data]]", headers=True)

# %%
#Align and combine adj_close columns for all four tickers by date
# Prepare and align the 'adj_close' data for all four tables by date
def extract_adj_close(df, ticker):
    temp = df[['date', 'adj_close']].copy()
    temp['date'] = pd.to_datetime(temp['date'])
    temp = temp.rename(columns={'adj_close': ticker})
    return temp.set_index('date')

msft = extract_adj_close(TableMSFT_df, 'MSFT')
aapl = extract_adj_close(TableAAPL_df, 'AAPL')
amzn = extract_adj_close(TableAMZN_df, 'AMZN')
googl = extract_adj_close(TableGOOGL_df, 'GOOGL')

# Combine all into a single DataFrame, aligning by date
adj_close_all = msft.join([aapl, amzn, googl], how='outer').sort_index()
adj_close_all.head()

# %%
#Normalized time series plot for Mar 2015 - Feb 2016
# Filter for the period March 2015 to February 2016
start_date = '2015-03-01'
end_date = '2016-02-29'
adj_close_period = adj_close_all.loc[start_date:end_date]

# Normalize all series to start at 100
adj_close_norm = adj_close_period.copy()
for col in adj_close_norm.columns:
    first_valid = adj_close_norm[col].first_valid_index()
    if first_valid is not None:
        adj_close_norm[col] = adj_close_norm[col] / adj_close_norm[col].loc[first_valid] * 100

plt.rcParams['font.family'] = ['DejaVu Sans']
fig, ax = plt.subplots(figsize=(10,6))
adj_close_norm.plot(ax=ax)
ax.set_title('Normalized Adjusted Close Price (Mar 2015 - Feb 2016)')
ax.set_xlabel('Date')
ax.set_ylabel('Normalized Price (Start = 100)')
ax.legend(title='Ticker')
plt.tight_layout()
plt.show()

# %%
# Save the previous plot as a high-resolution PNG
fig.savefig("../images/copilot_rebased_plot_clean.png", bbox_inches="tight", dpi=600)

# %%
#Normalized time series plot for Mar 2015 - Feb 2016
# Filter for the period March 2015 to February 2016
start_date = '2015-03-01'
end_date = '2016-02-29'
adj_close_period = adj_close_all.loc[start_date:end_date]

# Normalize all series to start at 100
adj_close_norm = adj_close_period.copy()
for col in adj_close_norm.columns:
    first_valid = adj_close_norm[col].first_valid_index()
    if first_valid is not None:
        adj_close_norm[col] = adj_close_norm[col] / adj_close_norm[col].loc[first_valid] * 100

plt.rcParams['font.family'] = ['DejaVu Sans']
fig, ax = plt.subplots(figsize=(10,6))
adj_close_norm.plot(ax=ax)
ax.set_title('Normalized Adjusted Close Price (Mar 2015 - Feb 2016)')
ax.set_xlabel('Date')
ax.set_ylabel('Normalized Price (Start = 100)')
ax.legend(title='Ticker')

# Add vertical line and label
black_monday = pd.to_datetime('2015-08-24')
ax.axvline(black_monday, color='red', linestyle='--'
, linewidth=2)
ax.annotate('Black Monday',
xy=(black_monday, ax.get_ylim()[1]),
xytext=(10,
-30),
textcoords='offset points',
arrowprops=dict(arrowstyle='-|>', color='red'),
color='red',
fontsize=10,
ha='left',
va='top')

plt.tight_layout()
plt.show()

# %%
# Save the previous plot as a high-resolution PNG
fig.savefig("../images/copilot_blackmonday_clean.png", bbox_inches="tight", dpi=600)

# %% [markdown]
# # reviews.xlsx

# %%
# Partial function for stocks.xlsx
xl = partial(xl_base, wb_path="/Users/felix/dev/python-for-excel-2e/src/xl/reviews.xlsx")

# %%
TableReviews_df=xl("TableReviews[[#Headers],[#Data]]", headers=True)

# %%
#Visualize most common words in reviews using a word cloud
import nltk
from nltk.corpus import stopwords
from collections import Counter
from wordcloud import WordCloud

# Combine all reviews into one text
all_reviews = ' '.join(TableReviews_df['Review'].astype(str))

# Tokenize and remove stopwords
stop_words = set(stopwords.words('english'))
words = [word.lower() for word in all_reviews.split() if word.isalpha() and word.lower() not in stop_words]

# Count word frequencies
word_freq = Counter(words)

# Create a word cloud
plt.rcParams['font.family'] = ['Meiryo','Batang','TH SarabunPSK','SimHei','DejaVu Sans']
fig, ax = plt.subplots(figsize=(8, 4))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis('off')
plt.tight_layout()
plt.show()

# %%
# Save the previous plot as a high-resolution PNG
fig.savefig("../images/copilot_wordcloud_clean.png", bbox_inches="tight", dpi=600)

# %%
#Count of reviews by sentiment label
# Perform sentiment analysis on each review
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon', quiet=True)

sia = SentimentIntensityAnalyzer()
TableReviews_df['SentimentScore'] = TableReviews_df['Review'].astype(str).apply(lambda x: sia.polarity_scores(x)['compound'])
TableReviews_df['SentimentLabel'] = TableReviews_df['SentimentScore'].apply(lambda x: 'Positive' if x > 0.05 else ('Negative' if x < -0.05 else 'Neutral'))

# Show sentiment label counts
sentiment_counts = TableReviews_df['SentimentLabel'].value_counts()
sentiment_counts

# %%
#Show each review with its sentiment label
# Show the review text with its classified sentiment
TableReviews_df[['Review', 'SentimentLabel']]
